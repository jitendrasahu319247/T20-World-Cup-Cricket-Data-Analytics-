# %%
import pandas as pd
import json

# %% [markdown]
# **Processing Match Results**

# %%
with open('/content/t20_world_cup_results.json') as f:
    data = json.load(f)

# Access the 'matchSummary' key directly instead of using index 0
df_match = pd.DataFrame(data['matchSummary'])
df_match.head()
# Out:
#          team1     team2    winner      margin     ground     matchDate  \
# 0      England  Pakistan   England   5 wickets  Melbourne  Nov 13, 2022
# 1      England     India   England  10 wickets   Adelaide  Nov 10, 2022
# 2  New Zealand  Pakistan  Pakistan   7 wickets     Sydney   Nov 9, 2022
# 3        India  Zimbabwe     India     71 runs  Melbourne   Nov 6, 2022
# 4   Bangladesh  Pakistan  Pakistan   5 wickets   Adelaide   Nov 6, 2022
#
#      scorecard
# 0  T20I # 1879
# 1  T20I # 1878
# 2  T20I # 1877
# 3  T20I # 1873
# 4  T20I # 1872

# %%
df_match.shape
# Out:
# (42, 7)

# %%
df_match.rename({'scorecard': 'match_id'}, axis = 1, inplace = True)
df_match.head()
# Out:
#          team1     team2    winner      margin     ground     matchDate  \
# 0      England  Pakistan   England   5 wickets  Melbourne  Nov 13, 2022
# 1      England     India   England  10 wickets   Adelaide  Nov 10, 2022
# 2  New Zealand  Pakistan  Pakistan   7 wickets     Sydney   Nov 9, 2022
# 3        India  Zimbabwe     India     71 runs  Melbourne   Nov 6, 2022
# 4   Bangladesh  Pakistan  Pakistan   5 wickets   Adelaide   Nov 6, 2022
#
#       match_id
# 0  T20I # 1879
# 1  T20I # 1878
# 2  T20I # 1877
# 3  T20I # 1873
# 4  T20I # 1872

# %%
match_ids_dict = {}

for index, row in df_match.iterrows():
    key1 = row['team1'] + ' Vs ' + row['team2']
    key2 = row['team2'] + ' Vs ' + row['team1']
    match_ids_dict[key1] = row['match_id']
    match_ids_dict[key2] = row['match_id']

# %%
df_match.to_csv('/content/t20_world_cup_results.csv', index = False)

# %% [markdown]
# **Processing Batting Summary**

# %%
with open('/content/t20_world_cup_batting_summary.json') as f:
    data = json.load(f)
    all_records = []
    for rec in data:
        all_records.extend(rec['battingSummary'])

df_batting = pd.DataFrame(all_records)
df_batting.head(11)
# Out:
#                   match teamInnings  battingPos          batsmanName  \
# 0   Pakistan Vs England    Pakistan           1    Mohammad Rizwan †
# 1   Pakistan Vs England    Pakistan           3       Babar Azam (c)
# 2   Pakistan Vs England    Pakistan           5       Mohammad Haris
# 3   Pakistan Vs England    Pakistan           7          Shan Masood
# 4   Pakistan Vs England    Pakistan           9       Iftikhar Ahmed
# 5   Pakistan Vs England    Pakistan          11          Shadab Khan
# 6   Pakistan Vs England    Pakistan          13       Mohammad Nawaz
# 7   Pakistan Vs England    Pakistan          15       Mohammad Wasim
# 8   Pakistan Vs England    Pakistan          17  Shaheen Shah Afridi
# 9   Pakistan Vs England    Pakistan          18           Haris Rauf
# 10  Pakistan Vs England     England           1     Jos Buttler (c)†
#
#                           dismissal runs balls 4s 6s      SR
# 0                          b Curran   15    14  0  1  107.14
# 1                      c & b Rashid   32    28  2  0  114.28
# 2                 c Stokes b Rashid    8    12  1  0   66.66
# 3            c Livingstone b Curran   38    28  2  1  135.71
# 4               c †Buttler b Stokes    0     6  0  0    0.00
# 5                 c Woakes b Jordan   20    14  2  0  142.85
# 6            c Livingstone b Curran    5     7  0  0   71.42
# 7            c Livingstone b Jordan    4     8  0  0   50.00
# 8                           not out    5     3  1  0  166.66
# 9                           not out    1     1  0  0  100.00
# 10  c †Mohammad Rizwan b Haris Rauf   26    17  3  1  152.94

# %%
df_batting['out/not_out'] = df_batting.dismissal.apply(lambda x: "out" if len(x)>0 else "not_out")
df_batting.head(11)
# Out:
#                   match teamInnings  battingPos          batsmanName  \
# 0   Pakistan Vs England    Pakistan           1    Mohammad Rizwan †
# 1   Pakistan Vs England    Pakistan           3       Babar Azam (c)
# 2   Pakistan Vs England    Pakistan           5       Mohammad Haris
# 3   Pakistan Vs England    Pakistan           7          Shan Masood
# 4   Pakistan Vs England    Pakistan           9       Iftikhar Ahmed
# 5   Pakistan Vs England    Pakistan          11          Shadab Khan
# 6   Pakistan Vs England    Pakistan          13       Mohammad Nawaz
# 7   Pakistan Vs England    Pakistan          15       Mohammad Wasim
# 8   Pakistan Vs England    Pakistan          17  Shaheen Shah Afridi
# 9   Pakistan Vs England    Pakistan          18           Haris Rauf
# 10  Pakistan Vs England     England           1     Jos Buttler (c)†
#
#                           dismissal runs balls 4s 6s      SR out/not_out
# 0                          b Curran   15    14  0  1  107.14         out
# 1                      c & b Rashid   32    28  2  0  114.28         out
# 2                 c Stokes b Rashid    8    12  1  0   66.66         out
# 3            c Livingstone b Curran   38    28  2  1  135.71         out
# 4               c †Buttler b Stokes    0     6  0  0    0.00         out
# 5                 c Woakes b Jordan   20    14  2  0  142.85         out
# 6            c Livingstone b Curran    5     7  0  0   71.42         out
# 7            c Livingstone b Jordan    4     8  0  0   50.00         out
# 8                           not out    5     3  1  0  166.66         out
# 9                           not out    1     1  0  0  100.00         out
# 10  c †Mohammad Rizwan b Haris Rauf   26    17  3  1  152.94         out

# %%
df_batting['match_id'] = df_batting['match'].map(match_ids_dict)
df_batting.head()
# Out:
#                  match teamInnings  battingPos        batsmanName  \
# 0  Pakistan Vs England    Pakistan           1  Mohammad Rizwan †
# 1  Pakistan Vs England    Pakistan           3     Babar Azam (c)
# 2  Pakistan Vs England    Pakistan           5     Mohammad Haris
# 3  Pakistan Vs England    Pakistan           7        Shan Masood
# 4  Pakistan Vs England    Pakistan           9     Iftikhar Ahmed
#
#                 dismissal runs balls 4s 6s      SR out/not_out     match_id
# 0                b Curran   15    14  0  1  107.14         out  T20I # 1879
# 1            c & b Rashid   32    28  2  0  114.28         out  T20I # 1879
# 2       c Stokes b Rashid    8    12  1  0   66.66         out  T20I # 1879
# 3  c Livingstone b Curran   38    28  2  1  135.71         out  T20I # 1879
# 4     c †Buttler b Stokes    0     6  0  0    0.00         out  T20I # 1879

# %%
df_batting.drop(columns=["dismissal"], inplace=True)
df_batting.head(10)
# Out:
#                  match teamInnings  battingPos          batsmanName runs  \
# 0  Pakistan Vs England    Pakistan           1    Mohammad Rizwan †   15
# 1  Pakistan Vs England    Pakistan           3       Babar Azam (c)   32
# 2  Pakistan Vs England    Pakistan           5       Mohammad Haris    8
# 3  Pakistan Vs England    Pakistan           7          Shan Masood   38
# 4  Pakistan Vs England    Pakistan           9       Iftikhar Ahmed    0
# 5  Pakistan Vs England    Pakistan          11          Shadab Khan   20
# 6  Pakistan Vs England    Pakistan          13       Mohammad Nawaz    5
# 7  Pakistan Vs England    Pakistan          15       Mohammad Wasim    4
# 8  Pakistan Vs England    Pakistan          17  Shaheen Shah Afridi    5
# 9  Pakistan Vs England    Pakistan          18           Haris Rauf    1
#
#   balls 4s 6s      SR out/not_out     match_id
# 0    14  0  1  107.14         out  T20I # 1879
# 1    28  2  0  114.28         out  T20I # 1879
# 2    12  1  0   66.66         out  T20I # 1879
# 3    28  2  1  135.71         out  T20I # 1879
# 4     6  0  0    0.00         out  T20I # 1879
# 5    14  2  0  142.85         out  T20I # 1879
# 6     7  0  0   71.42         out  T20I # 1879
# 7     8  0  0   50.00         out  T20I # 1879
# 8     3  1  0  166.66         out  T20I # 1879
# 9     1  0  0  100.00         out  T20I # 1879

# %%
df_batting['batsmanName'] = df_batting['batsmanName'].apply(lambda x: x.replace('â€', ''))
df_batting['batsmanName'] = df_batting['batsmanName'].apply(lambda x: x.replace('\xa0', ''))
df_batting.head()
# Out:
#                  match teamInnings  battingPos       batsmanName runs balls  \
# 0  Pakistan Vs England    Pakistan           1  Mohammad Rizwan†   15    14
# 1  Pakistan Vs England    Pakistan           3     Babar Azam(c)   32    28
# 2  Pakistan Vs England    Pakistan           5    Mohammad Haris    8    12
# 3  Pakistan Vs England    Pakistan           7       Shan Masood   38    28
# 4  Pakistan Vs England    Pakistan           9    Iftikhar Ahmed    0     6
#
#   4s 6s      SR out/not_out     match_id
# 0  0  1  107.14         out  T20I # 1879
# 1  2  0  114.28         out  T20I # 1879
# 2  1  0   66.66         out  T20I # 1879
# 3  2  1  135.71         out  T20I # 1879
# 4  0  0    0.00         out  T20I # 1879

# %%
df_batting.shape
# Out:
# (699, 11)

# %%
df_batting.to_csv('/content/t20_world_cup_batting_summary.csv', index = False)

# %% [markdown]
# **Process Bowling Summary**

# %%
with open('/content/t20_world_cup_bowling_summary.json') as f:
    data = json.load(f)
    all_records = []

    # Extract all bowling summaries from each record
    for rec in data:
        if 'bowlingSummary' in rec and isinstance(rec['bowlingSummary'], list):
            all_records.extend(rec['bowlingSummary'])

# Optionally create a DataFrame
df_bowling = pd.DataFrame(all_records)

# Convert DataFrame back to list of dictionaries if needed
bowling_list_of_dicts = df_bowling.to_dict(orient='records')

# Show the list of dictionaries (first few items)
print(bowling_list_of_dicts[:2])
# Out:
# [{'match': 'Pakistan Vs England', 'bowlingTeam': 'England', 'bowlerName': 'Ben Stokes', 'overs': '4', 'maiden': '0', 'runs': '32', 'wickets': '1', 'economy': '8.00', '0s': '6', '4s': '1', '6s': '0', 'wides': '2', 'noBalls': '1'}, {'match': 'Pakistan Vs England', 'bowlingTeam': 'England', 'bowlerName': 'Chris Woakes', 'overs': '3', 'maiden': '0', 'runs': '26', 'wickets': '0', 'economy': '8.66', '0s': '7', '4s': '2', '6s': '1', 'wides': '2', 'noBalls': '0'}]

# %%
df_bowling = pd.DataFrame(all_records)
print(df_bowling.shape)
df_bowling.head()
# Out:
# (500, 13)
#                  match bowlingTeam    bowlerName overs maiden runs wickets  \
# 0  Pakistan Vs England     England    Ben Stokes     4      0   32       1
# 1  Pakistan Vs England     England  Chris Woakes     3      0   26       0
# 2  Pakistan Vs England     England    Sam Curran     4      0   12       3
# 3  Pakistan Vs England     England   Adil Rashid     4      1   22       2
# 4  Pakistan Vs England     England  Chris Jordan     4      0   27       2
#
#   economy  0s 4s 6s wides noBalls
# 0    8.00   6  1  0     2       1
# 1    8.66   7  2  1     2       0
# 2    3.00  15  0  0     0       0
# 3    5.50  10  1  0     1       0
# 4    6.75   9  3  0     0       0

# %%
df_bowling['match_id'] = df_bowling['match'].map(match_ids_dict)
df_bowling.head()
# Out:
#                  match bowlingTeam    bowlerName overs maiden runs wickets  \
# 0  Pakistan Vs England     England    Ben Stokes     4      0   32       1
# 1  Pakistan Vs England     England  Chris Woakes     3      0   26       0
# 2  Pakistan Vs England     England    Sam Curran     4      0   12       3
# 3  Pakistan Vs England     England   Adil Rashid     4      1   22       2
# 4  Pakistan Vs England     England  Chris Jordan     4      0   27       2
#
#   economy  0s 4s 6s wides noBalls     match_id
# 0    8.00   6  1  0     2       1  T20I # 1879
# 1    8.66   7  2  1     2       0  T20I # 1879
# 2    3.00  15  0  0     0       0  T20I # 1879
# 3    5.50  10  1  0     1       0  T20I # 1879
# 4    6.75   9  3  0     0       0  T20I # 1879

# %%
df_bowling.to_csv('/content/t20_world_cup_bowling_summary.csv', index = False)

# %% [markdown]
# **Process Players Information**

# %%
with open('/content/t20_world_cup_player_info.json') as f:
    data = json.load(f)

# %%
df_players = pd.DataFrame(data)

print(df_players.shape)
df_players.head(10)
# Out:
# (1199, 6)
#                   name      team    battingStyle            bowlingStyle  \
# 0    Mohammad Rizwan †  Pakistan  Right hand Bat        Right arm Medium
# 1       Babar Azam (c)  Pakistan  Right hand Bat      Right arm Offbreak
# 2       Mohammad Haris  Pakistan  Right hand Bat      Right arm Offbreak
# 3          Shan Masood  Pakistan   Left hand Bat   Right arm Medium fast
# 4       Iftikhar Ahmed  Pakistan  Right hand Bat      Right arm Offbreak
# 5          Shadab Khan  Pakistan  Right hand Bat                Legbreak
# 6       Mohammad Nawaz  Pakistan   Left hand Bat  Slow Left arm Orthodox
# 7       Mohammad Wasim  Pakistan  Right hand Bat   Right arm Fast medium
# 8  Shaheen Shah Afridi  Pakistan   Left hand Bat           Left arm Fast
# 9           Haris Rauf  Pakistan  Right hand Bat          Right arm Fast
#
#            playingRole                                        description
# 0  Wicketkeeper Batter  For several years, it appeared Mohammad Rizwan...
# 1               Batter  A right-hand, top-order batsman known for his ...
# 2  Wicketkeeper Batter                                                N/A
# 3       Opening Batter  A solid and technically sound left-hand opener...
# 4  Middle order Batter  In 2023, making what seemed to be his nth come...
# 5           Allrounder  A prodigious turner of the ball, teenage legsp...
# 6           Allrounder  Mohammad Nawaz started out in cricket at the a...
# 7   Bowling Allrounder                                                N/A
# 8               Bowler  A baby face perched on a two-metre body, Shahe...
# 9               Bowler  By and large, the quixotic idea of a Pakistan ...

# %%
df_players['name'] = df_players['name'].apply(lambda x: x.replace('â€', ''))
df_players['name'] = df_players['name'].apply(lambda x: x.replace('†', ''))
df_players['name'] = df_players['name'].apply(lambda x: x.replace('\xa0', ''))
df_players.head(10)
# Out:
#                   name      team    battingStyle            bowlingStyle  \
# 0      Mohammad Rizwan  Pakistan  Right hand Bat        Right arm Medium
# 1        Babar Azam(c)  Pakistan  Right hand Bat      Right arm Offbreak
# 2       Mohammad Haris  Pakistan  Right hand Bat      Right arm Offbreak
# 3          Shan Masood  Pakistan   Left hand Bat   Right arm Medium fast
# 4       Iftikhar Ahmed  Pakistan  Right hand Bat      Right arm Offbreak
# 5          Shadab Khan  Pakistan  Right hand Bat                Legbreak
# 6       Mohammad Nawaz  Pakistan   Left hand Bat  Slow Left arm Orthodox
# 7       Mohammad Wasim  Pakistan  Right hand Bat   Right arm Fast medium
# 8  Shaheen Shah Afridi  Pakistan   Left hand Bat           Left arm Fast
# 9           Haris Rauf  Pakistan  Right hand Bat          Right arm Fast
#
#            playingRole                                        description
# 0  Wicketkeeper Batter  For several years, it appeared Mohammad Rizwan...
# 1               Batter  A right-hand, top-order batsman known for his ...
# 2  Wicketkeeper Batter                                                N/A
# 3       Opening Batter  A solid and technically sound left-hand opener...
# 4  Middle order Batter  In 2023, making what seemed to be his nth come...
# 5           Allrounder  A prodigious turner of the ball, teenage legsp...
# 6           Allrounder  Mohammad Nawaz started out in cricket at the a...
# 7   Bowling Allrounder                                                N/A
# 8               Bowler  A baby face perched on a two-metre body, Shahe...
# 9               Bowler  By and large, the quixotic idea of a Pakistan ...

# %%
df_players[df_players['team'] == 'India']
# Out:
#                     name   team    battingStyle  \
# 29              KL Rahul  India  Right hand Bat
# 30       Rohit Sharma(c)  India  Right hand Bat
# 31           Virat Kohli  India  Right hand Bat
# 32      Suryakumar Yadav  India  Right hand Bat
# 33         Hardik Pandya  India  Right hand Bat
# ..                   ...    ...             ...
# 759       Arshdeep Singh  India   Left hand Bat
# 760       Mohammed Shami  India  Right hand Bat
# 761        Hardik Pandya  India  Right hand Bat
# 762  Ravichandran Ashwin  India  Right hand Bat
# 763           Axar Patel  India   Left hand Bat
#
#                              bowlingStyle          playingRole  \
# 29                                    N/A  Wicketkeeper Batter
# 30                     Right arm Offbreak     Top order Batter
# 31                       Right arm Medium     Top order Batter
# 32   Right arm Medium, Right arm Offbreak               Batter
# 33                  Right arm Medium fast           Allrounder
# ..                                    ...                  ...
# 759                  Left arm Medium fast               Bowler
# 760                        Right arm Fast               Bowler
# 761                 Right arm Medium fast           Allrounder
# 762                    Right arm Offbreak   Bowling Allrounder
# 763                Slow Left arm Orthodox           Allrounder
#
#                                            description
# 29                             KL Rahul player profile
# 30                         Rohit Sharma player profile
# 31                          Virat Kohli player profile
# 32                     Suryakumar Yadav player profile
# 33                        Hardik Pandya player profile
# ..                                                 ...
# 759                      Arshdeep Singh player profile
# 760  Mohammed Shami was India's leading fast bowler...
# 761                       Hardik Pandya player profile
# 762                            R Ashwin player profile
# 763                         Axar Patel player profile
#
# [80 rows x 6 columns]

# %%
df_players.to_csv('/content/t20_world_cup_player_info.csv', index = False)
